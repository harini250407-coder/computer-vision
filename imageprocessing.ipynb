# %%
import numpy as np
import cv2

# %%
image=cv2.imread('/content/tvk.jpg')
gray_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
edges=cv2.Canny(gray_image,75,100)
from google.colab.patches import cv2_imshow
cv2_imshow(image)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=RGB size=236x419>
# <PIL.Image.Image image mode=L size=236x419>
