# %%
import cv2
cv2.__version__
# Out:
# '4.13.0'

# %%
img = cv2.imread('/content/kedharnath.jpg')
print(img)
# Out:
# [[[219 219 219]
#   [219 219 219]
#   [218 218 218]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [237 237 237]]
#
#  [[210 210 210]
#   [211 211 211]
#   [211 211 211]
#   ...
#   [240 240 240]
#   [239 239 239]
#   [239 239 239]]
#
#  [[204 204 204]
#   [205 205 205]
#   [207 207 207]
#   ...
#   [242 242 242]
#   [242 242 242]
#   [241 241 241]]
#
#  ...
#
#  [[172 172 172]
#   [185 185 185]
#   [178 178 178]
#   ...
#   [151 151 151]
#   [161 161 161]
#   [147 147 147]]
#
#  [[164 164 164]
#   [191 191 191]
#   [186 186 186]
#   ...
#   [124 124 124]
#   [144 144 144]
#   [128 128 128]]
#
#  [[185 185 185]
#   [180 180 180]
#   [166 166 166]
#   ...
#   [ 17  17  17]
#   [ 96  96  96]
#   [ 15  15  15]]]

# %%
#to display images imshow we need to import patches only in colab
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=255x198>

# %%
# to read it in black nd white put,0
img1 = cv2.imread('/content/kedharnath.jpg',0)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=L size=255x198>

# %%
cv2.imwrite('/content/kedharnath.jpg',img1)
# Out:
# True

# %%
print(img.size)
# Out:
# 151470

# %%
print(img.shape)
# Out:
# (198, 255, 3)

# %%
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
img2=img[1:100,25:254]
img2
# Out:
# array([[[ 62,  62,  62],
#         [ 73,  73,  73],
#         [ 73,  73,  73],
#         ...,
#         [241, 241, 241],
#         [240, 240, 240],
#         [239, 239, 239]],
#
#        [[107, 107, 107],
#         [125, 125, 125],
#         [137, 137, 137],
#         ...,
#         [243, 243, 243],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        [[136, 136, 136],
#         [159, 159, 159],
#         [185, 185, 185],
#         ...,
#         [245, 245, 245],
#         [244, 244, 244],
#         [243, 243, 243]],
#
#        ...,
#
#        [[ 42,  42,  42],
#         [ 33,  33,  33],
#         [ 51,  51,  51],
#         ...,
#         [ 56,  56,  56],
#         [ 51,  51,  51],
#         [ 50,  50,  50]],
#
#        [[ 49,  49,  49],
#         [ 44,  44,  44],
#         [ 59,  59,  59],
#         ...,
#         [ 53,  53,  53],
#         [ 60,  60,  60],
#         [ 64,  64,  64]],
#
#        [[ 68,  68,  68],
#         [ 71,  71,  71],
#         [ 54,  54,  54],
# ...

# %%
#image rotating
img3=cv2.rotate(img,cv2.ROTATE_90_COUNTERCLOCKWISE)
from google.colab.patches import cv2_imshow
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=198x255>

# %%
img4=cv2.rotate(img,cv2.ROTATE_180)
from google.colab.patches import cv2_imshow
cv2_imshow(img4)
# Out:
# <PIL.Image.Image image mode=RGB size=255x198>

# %%
img3=cv2.rotate(img,cv2.ROTATE_90_CLOCKWISE)
from google.colab.patches import cv2_imshow
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=198x255>

# %%
#vertical flip
img4=cv2.flip(img,1)
from google.colab.patches import cv2_imshow
cv2_imshow(img4)
# Out:
# <PIL.Image.Image image mode=RGB size=255x198>

# %%
#horizontal flip
img5=cv2.flip(img,0)
from google.colab.patches import cv2_imshow
cv2_imshow(img5)
# Out:
# <PIL.Image.Image image mode=RGB size=255x198>

# %%
img6=cv2.resize(img,(450,400))
from google.colab.patches import cv2_imshow
cv2_imshow(img6)
# Out:
# <PIL.Image.Image image mode=RGB size=450x400>

# %%
img7=cv2.blur(img,(1,50))
from google.colab.patches import cv2_imshow
cv2_imshow(img7)
# Out:
# <PIL.Image.Image image mode=RGB size=255x198>
